# %% [markdown]
# ## Audio Overview
#
# L’audio è essenziale in un videogioco (musica, effetti, ambiente).
# Unity permette di:
#
# * importare i principali formati audio
# * riprodurre suoni in **2D e 3D**
# * applicare effetti come **eco e filtri**
# * registrare audio tramite **microfono**
#
# ## Teoria di base
#
# Nel mondo reale il suono è influenzato da:
#
# * distanza e direzione
# * velocità (Effetto Doppler)
# * ambiente (eco, riflessioni)
#
# Unity simula questi comportamenti per rendere l’audio realistico.
#
# ## Audio Source e Audio Listener
#
# * **Audio Source**: sorgente del suono, collegata a un GameObject
# * **Audio Listener**: punto di ascolto, di solito sulla Main Camera
#
# Unity calcola volume, direzione e Doppler in base alla posizione relativa.
#
# ## Effetti ambientali
#
# * **Audio Filters**: effetti applicati alle sorgenti (es. Echo)
# * **Reverb Zones**: aree che modificano il suono quando si entra o si esce (tunnel, stanze)
#
# ## Audio Mixer
#
# Serve per:
#
# * organizzare le sorgenti (Music, SFX, UI)
# * applicare effetti
# * gestire mix e mastering
#
# ## Asset audio
#
# Formati supportati:
#
# * WAV, AIFF, MP3, OGG
# * moduli musicali: XM, MOD, IT, S3M
#
# I file importati diventano **Audio Clip**.
#
# ## Registrazione audio
#
# Tramite la classe `Microphone` è possibile:
#
# * accedere ai microfoni
# * registrare audio in tempo reale
# * creare Audio Clip via script
#
# ---

# %% [markdown]
# ## Introduzione ai file audio in Unity
#
# Il workflow dei file audio in Unity è simile a quello di **Mesh** e **Texture**: semplice e integrato. Unity supporta quasi tutti i formati audio comuni, ma è importante conoscere alcune impostazioni chiave per gestirli correttamente.
#
# ## Audio Data vs Audio Clip
#
# * **Audio Data**
#   È il dato grezzo del file audio:
#   durata, numero di canali, sample rate, formato di compressione.
#
# * **Audio Clip**
#   È l’asset Unity che **contiene e processa** l’audio data per il motore.
#   Gli **Audio Source** riproducono sempre **Audio Clip**, non direttamente i file.
#
# ## Import Settings e gestione memoria
#
# Le **Audio Clip Import Settings** determinano come l’audio viene caricato a runtime:
#
# * **In memoria**
#   Per suoni frequenti o imprevedibili (passi, armi, impatti)
#
# * **On-demand / streaming**
#   Per dialoghi, musica, ambient loop
#   → riduce l’uso di memoria e migliora le prestazioni
#
# ## Uso degli audio via script
#
# Ogni file audio importato è accessibile da script come **AudioClip**.
#
# * Le informazioni (durata, canali, sample rate) sono disponibili **prima** del caricamento dell’audio
# * Utile per:
#
#   * sistemi musicali dinamici
#   * sequenziamento automatico
#   * dialoghi temporizzati
#
# Unity carica in memoria **solo i clip necessari**, ottimizzando le risorse.
#
# ### Concetto chiave
#
# > **AudioClip = contenitore intelligente** che separa dati audio, metadati e caricamento runtime.
#
# Se vuoi, nel prossimo passo posso:
#
# * confrontare **Load In Memory vs Streaming**
# * spiegare **compressione audio per piattaforma**
# * collegare tutto a **performance e build size**
#
# ---

# %% [markdown]
# ## Compatibilità dei formati audio
#
# Unity supporta diversi formati audio che possono essere importati e utilizzati come **Audio Clip**.
#
# * Supporta audio **mono, stereo e multicanale**
# * Fino a **8 canali** (surround)
#
# ## Formati audio supportati
#
# Unity permette di importare i seguenti file:
#
# * **MP3** → `.mp3`
# * **AIFF** → `.aiff`, `.aif`
# * **WAV** → `.wav`
# * **Ogg Vorbis** → `.ogg`
# * **FLAC** → `.flac`
#
# Dopo l’importazione, Unity gestisce la **compressione interna** in base alle impostazioni di build e piattaforma.
#
# ## Tracker modules (musica modulare)
#
# Sono supportati anche i moduli tracker:
#
# * **MOD** → `.mod`
# * **XM** → `.xm`
# * **IT** → `.it`
# * **S3M** → `.s3m`
#
# Questi asset:
#
# * si comportano come normali Audio Clip
# * **non mostrano la waveform preview** nell’Inspector
#
# ### Punto chiave
#
# > Unity accetta molti formati in input, ma **decide lui come ricomprimerli** per runtime e piattaforma.
#
# Se vuoi, posso:
#
# * dirti **quale formato conviene usare** (SFX vs musica)
# * spiegare **FLAC vs WAV vs OGG** in ottica performance
# * collegare i formati a **mobile / PC / console**
#
# ---

# %% [markdown]
# ## Tracker Modules
#
# I **Tracker Modules** sono pacchetti di **sample audio** organizzati e sequenziati in modo programmatico.
# Nascono negli anni ’80 (soprattutto su **Amiga**) e sono stati molto usati nei primi videogiochi e nella demo-scene.
#
# Sono concettualmente simili ai **file MIDI**:
#
# * le tracce contengono istruzioni su **quando** suonare un suono, a **che pitch** e **volume**
# * la melodia viene ricostruita a runtime
#
# La differenza chiave è che:
#
# * il **MIDI** dipende dalla sound bank dell’hardware (suona diverso su sistemi diversi)
# * i **Tracker Modules** includono **sample PCM**, garantendo un suono coerente ovunque
#
# ## Formati supportati
#
# Unity supporta i 4 formati più comuni:
#
# * **IT** – Impulse Tracker (`.it`)
# * **S3M** – Scream Tracker (`.s3m`)
# * **XM** – Extended Module (`.xm`)
# * **MOD** – Module (`.mod`)
#
# ## Vantaggi principali
#
# * **Dimensioni molto ridotte**
# * Nessuna perdita percepibile di qualità
# * Un singolo sample può funzionare come **strumento**, variando pitch e volume
# * Ideali per giochi dove:
#
#   * serve musica
#   * il **peso del download** è un problema
#
# ## Tool di terze parti
#
# Per creare e modificare Tracker Modules si usano soprattutto:
#
# * **MilkyTracker** (macOS)
# * **OpenMPT** (Windows)
#
# ### Concetto chiave
#
# > **Tracker Modules = musica procedurale basata su sample**, leggera, coerente e perfetta per il game development.
#
# ---

# %% [markdown]
# ## Audio Mixer
#
# Unity fornisce l’**Audio Mixer** per:
#
# * mixare più sorgenti audio
# * applicare effetti
# * gestire il mastering dell’audio di gioco
#
# ## Audio Mixer Window
#
# L’Audio Mixer è strutturato come un **albero di Mixer Groups (bus)**.
#
# Ogni **Audio Mixer Group**:
#
# * riceve segnali audio
# * controlla **volume e pitch**
# * applica una **catena di effetti**
# * supporta **send & return** per inviare il segnale ad altri bus
#
# ## Audio Mixer come asset
#
# * L’Audio Mixer è un **asset**
# * Puoi avere **più mixer attivi** contemporaneamente
# * Ogni mixer ha sempre un **Master Group**
# * Altri gruppi servono a organizzare l’audio (Music, SFX, UI, ecc.)
#
# Nota: il supporto **Web** è solo parziale.
#
# ## Come funziona
#
# * Un **Audio Source** invia il suo output a un **Mixer Group**
# * Gli effetti del gruppo vengono applicati al segnale
# * L’output di un mixer può essere **instradato in altri mixer**
#   → permette routing complessi e catene di effetti avanzate
#
# ## Snapshots
#
# * Salvano lo stato di tutti i parametri del mixer
# * Permettono transizioni dinamiche tra mix diversi
# * Utili per cambiare **mood**, tensione o situazione di gameplay
#
# ## Ducking
#
# * Un gruppo abbassa automaticamente il volume di un altro
# * Tipico esempio: musica che si abbassa durante un dialogo
#
# ## Views
#
# * Permettono di **nascondere o mostrare gruppi**
# * Utile per lavorare su mixer complessi
# * Si può passare da una view all’altra
#
# ### Concetto chiave
#
# > **Audio Mixer = centro di controllo dell’audio**, fondamentale per mix dinamici, effetti avanzati e audio reattivo al gameplay.
#
# ---

# %% [markdown]
# ## Cos’è l’Audio Mixer
#
# Unity **Audio Mixer** è un **asset** che si interpone tra **Audio Source** e **Audio Listener**, permettendo **routing, mixing ed effetti avanzati** sull’audio.
# Il mix avviene tramite una **gerarchia di Audio Groups** (categorie di suoni).
#
# ## Come funziona (in breve)
#
# * Gli **Audio Source** inviano il segnale a un **Audio Group**
# * Il segnale viene:
#
#   * mixato
#   * attenuato
#   * processato con **DSP effects**
# * Alla fine arriva all’**Audio Listener**
# * I mixer possono essere **concatenati tra loro**
#
# 👉 Il mixing è **ortogonale alla Scene Hierarchy**: l’audio non segue la struttura degli oggetti di scena.
#
# ## Audio Mixer View (elementi principali)
#
# * **Asset**: contiene gruppi e snapshot
# * **Hierarchy**: struttura degli Audio Groups
# * **Mixer Views**: viste filtrate della gerarchia
# * **Snapshots**: stati salvati del mix
# * **Output Audio Mixer**: routing verso altri mixer
# * **AudioGroup Strip**: volume, mute/solo, VU meter, effetti
# * **Edit in Play Mode**: modifica in runtime
# * **Exposed Parameters**: parametri controllabili via script
#
# ## Audio Mixer Inspector
#
# Per ogni Audio Group puoi gestire:
#
# * **Pitch & Ducking**
# * **Send / Return**
# * **Attenuation (volume)**
# * **Effetti DSP** (es. Reverb)
# * Parametri **esponibili a script**
#
# ## Routing e Mixing (concetto chiave)
#
# * Un Audio Group:
#
#   * riceve **n input**
#   * produce **1 output**
# * Serve per:
#
#   * categorizzare i suoni
#   * applicare effetti a interi gruppi
#   * fare **mastering dinamico**
#
# ## Relazione con l’audio 3D
#
# Effetti legati allo spazio (distanza, Doppler, reverb ambientale):
#
# * vengono applicati **prima**, sull’**Audio Source**
# * poi il segnale entra nel Mixer (categorie)
#
# ## Categorie sonore
#
# Il Mixer permette di organizzare il soundscape, ad esempio:
#
# * Master
#
#   * Music
#   * UI
#   * Game
#
#     * Dialog
#     * Ambience
#     * Foley (passi, armi, ecc.)
#
# Questo evita caos sonoro e abilita **ducking** e controlli globali.
#
# ## Moods, Themes e Global Mix
#
# * L’Audio Mixer rappresenta il **mix globale** del gioco
# * È sempre presente nella scena
# * Le istanze audio passano tutte da lì
# ## Snapshots
#
# Gli **Audio Snapshots** salvano lo stato del mixer:
#
# * volume
# * pitch
# * send
# * wet mix
# * parametri degli effetti
#
# Permettono **transizioni di mood** (es. esplorazione → combattimento → dialogo).
#
# ### Concetto chiave finale
#
# > **Audio Mixer = cervello del soundscape**, separa lo spazio 3D dalla logica del mix e rende l’audio dinamico, controllabile e narrativo.
#
# ---

# %% [markdown]
# ## Audio Mixer Window – Sintesi
#
# | Pannello             | A cosa serve         | Funzioni principali                                      |
# | -------------------- | -------------------- | -------------------------------------------------------- |
# | **Mixers**           | Gestione Audio Mixer | Lista mixer, crea nuovi mixer, routing tra mixer         |
# | **Hierarchy**        | Categorie sonore     | Crea, organizza e struttura gli **Audio Groups**         |
# | **AudioGroup View**  | Mix operativo        | VU meter, volume (dB), Solo / Mute / Bypass, effetti DSP |
# | **Snapshots**        | Stati del mix        | Salva e cambia mood (volume, effetti, send, pitch)       |
# | **Views**            | Workflow visivo      | Filtra Audio Groups visibili (non influisce sul runtime) |
# | **Eye & Color Tags** | Organizzazione       | Mostra/nasconde gruppi e li colora per categoria         |
#
# ### Punti chiave
#
# * Gli **Audio Groups** funzionano come **bus**
# * Il mixer è **ortogonale alla scena**
# * **Snapshots = mix dinamico a runtime**
# * Le **Views** servono solo all’editor
#
# ---

# %% [markdown]
# ## AudioGroup Inspector – Riassunto
#
# | Sezione                  | Cos’è                   | A cosa serve                                           |
# | ------------------------ | ----------------------- | ------------------------------------------------------ |
# | **Inspector Header**     | Nome gruppo + menu ⚙️   | Copia settaggi su tutti gli Snapshot, mostra uso CPU   |
# | **Edit in Play Mode**    | Override snapshot       | Modifica il mix **durante il Play Mode**               |
# | **Pitch**                | Controllo pitch globale | Altera l’intonazione del gruppo                        |
# | **Attenuation Unit**     | Volume del Group        | Gain / attenuazione (-80 dB → +20 dB) con **VU meter** |
# | **Effect Units**         | DSP effects             | EQ, HPF, Reverb, ecc. (ordinabili)                     |
# | **Send Units**           | Side-chain send         | Invia segnale ad altri effetti                         |
# | **Receive Units**        | Side-chain receive      | Riceve segnale dai Send                                |
# | **Duck Volume**          | Side-chain compression  | Abbassa volume in base ad altri segnali                |
# | **Wet Mixing**           | Dry / Wet               | Quanto segnale passa nell’effetto                      |
# | **Exposed Parameters**   | Controllo via script    | Bypass snapshot e controllo runtime                    |
# | **Transition Overrides** | Curve snapshot          | Cambia comportamento delle transizioni                 |
#
# ## Concetti chiave (super sintetici)
#
# * **Ogni AudioGroup ha sempre 1 Attenuation Unit**
# * Gli **effetti sono una catena DSP**, riordinabile
# * **Send / Receive / Duck** = side-chain audio
# * **VU meter** mostra RMS + peak
# * **Exposed parameters** → controllo diretto via codice
# * **Snapshots** controllano i valori, salvo override
#
# ## Audio Mixer Inspector (asset)
#
# | Funzione               | Descrizione                                |
# | ---------------------- | ------------------------------------------ |
# | **Auto Mixer Suspend** | Sospende il mixer quando non produce suono |
# | **CPU optimization**   | Evita mixer attivi inutilmente             |
# | **Activation logic**   | Mixer attivo finché riceve audio           |
#
# ---
#
# ### Frase da ricordare (da esame)
#
# > **AudioGroup Inspector = catena DSP + volume + side-chain + controllo snapshot/script**, tutto applicato a una categoria sonora.
#
# ---

# %% [markdown]
# ## Audio Random Container – Cos’è
#
# Un **Audio Random Container** è un asset per gestire **playlist di AudioClip** con **randomizzazione controllata**.
# È pensato soprattutto per **SFX ripetitivi**: passi, colpi, armi, impatti, props.
#
# ## Proprietà principali
#
# ### Controlli base
#
# | Proprietà                | Funzione                                 |
# | ------------------------ | ---------------------------------------- |
# | **Play**                 | Avvia / ferma anteprima playlist         |
# | **Skip**                 | Passa al clip successivo                 |
# | **Volume**               | Volume globale (0–1, in dB)              |
# | **Volume Randomization** | Variazione casuale del volume            |
# | **Pitch**                | Pitch globale (additivo con AudioSource) |
# | **Pitch Randomization**  | Variazione casuale del pitch             |
#
# ### Gestione Audio Clips
#
# | Proprietà                 | Funzione                         |
# | ------------------------- | -------------------------------- |
# | **Audio Clips**           | Lista dei clip                   |
# | **Enable / Disable clip** | Attiva o disattiva singoli clip  |
# | **Clip Volume**           | Volume individuale per ogni clip |
# | **Reorder**               | Cambia ordine di riproduzione    |
#
# ### Trigger
#
# | Modalità      | Descrizione                                |
# | ------------- | ------------------------------------------ |
# | **Manual**    | Riproduzione solo via `AudioSource.Play()` |
# | **Automatic** | Trigger interno automatico                 |
#
# ### Playback Mode
#
# | Modalità                 | Comportamento                                            |
# | ------------------------ | -------------------------------------------------------- |
# | **Sequential**           | Riproduce in ordine                                      |
# | **Shuffle**              | Nessuna ripetizione finché tutti i clip non sono suonati |
# | **Random**               | Scelta casuale con possibili ripetizioni                 |
# | **Avoid Repeating Last** | Evita ripetizione degli ultimi N clip                    |
# ### Automatic Trigger Mode
#
# | Modalità               | Uso tipico                             |
# | ---------------------- | -------------------------------------- |
# | **Pulse**              | Intervalli fissi (es. arma automatica) |
# | **Offset**             | Pausa dopo la fine del clip precedente |
# | **Time**               | Durata intervallo                      |
# | **Time Randomization** | Variazione casuale del tempo           |
#
# ### Loop
#
# | Modalità                | Descrizione                   |
# | ----------------------- | ----------------------------- |
# | **Infinite**            | Non si ferma mai              |
# | **Clips**               | Loop basato su numero di clip |
# | **Cycles**              | Loop basato su cicli completi |
# | **Count**               | Numero di clip o cicli        |
# | **Count Randomization** | Variazione casuale del loop   |
#
# ## Concetto chiave (da ricordare)
#
# > **Audio Random Container = varietà sonora senza scripting complesso**, perfetto per evitare ripetizioni artificiali negli SFX.
#
# ---

# %% [markdown]
# ## Audio Random Container – Fondamentali
#
# Unity **Audio Random Container** è un asset che permette di creare **playlist audio** con **regole di riproduzione** (random, loop, timing).
# È ideale per **SFX variabili** e **musica dinamica** (footsteps, armi, ambient, musiche).
#
# ## Concetti chiave
#
# ### Audio Cycle
#
# | Concetto        | Significato                               |
# | --------------- | ----------------------------------------- |
# | **Audio Cycle** | Un ciclo completo della lista Audio Clips |
# | **Esempio**     | 3 clip → 1 ciclo = 3 clip suonati         |
#
# ### AudioSource API (differenze importanti)
#
# | API                       | Comportamento                                           |
# | ------------------------- | ------------------------------------------------------- |
# | **AudioSource.isPlaying** | `true` quando il container sta suonando **un clip**     |
# | **AudioSource.Play**      | Dipende dalla modalità del container                    |
# | **Manual**                | `Play()` riproduce **un clip** secondo il Playback Mode |
# | **Automatic**             | Il container gestisce autonomamente la riproduzione     |
#
# Esempio:
#
# * Playback Mode = **Random**
# * `AudioSource.Play()` → suona **un clip casuale** dalla lista
#
# ## In una frase (da esame)
#
# > **Audio Random Container = playlist intelligente** controllata via AudioSource, con cicli, randomizzazione e logica interna.
#
# ---

# %% [markdown]
# ## Creare una playlist randomizzata (overview)
#
# Una **playlist randomizzata** si ottiene creando un **Audio Random Container** e riproducendolo tramite un **Audio Source**.
# È ideale per **footsteps, impatti, dialoghi AI, SFX variabili**.
#
# ## Prerequisiti
#
# | Devi saper fare                  |
# | -------------------------------- |
# | Creare un GameObject             |
# | Aggiungere un Button             |
# | Creare un Audio Random Container |
#
# ## Creare un Audio Random Container
#
# | Metodo           | Percorso                                               |
# | ---------------- | ------------------------------------------------------ |
# | **Menu**         | Assets → Create → Audio → Audio Random Container       |
# | **Project view** | Click destro → Create → Audio → Audio Random Container |
# | **Window**       | Window → Audio → Audio Random Container                |
#
# Nota: trascinare un **Audio Random Container** nella Hierarchy crea automaticamente un **GameObject con Audio Source** (posizione 0,0,0).
#
# ## Riprodurre un Audio Random Container
#
# ### Integrazione con Audio Source
#
# | Passo | Azione                                               |
# | ----- | ---------------------------------------------------- |
# | 1     | Crea un GameObject                                   |
# | 2     | Add Component → Audio → Audio Source                 |
# | 3     | Assegna l’Audio Random Container a **AudioResource** |
# | 4     | Riproduci via Play On Awake, API o trigger           |
#
# 👉 **L’Audio Source è obbligatorio**: è l’emettitore (2D / 3D).
#
# ## Uso con Game Triggers (es. Button)
#
# | Passo | Azione                             |
# | ----- | ---------------------------------- |
# | 1     | Aggiungi un Button alla scena      |
# | 2     | Inspector → On Click → `+`         |
# | 3     | Seleziona Audio Source / Container |
# | 4     | Triggera la riproduzione           |
#
# ## Concetto chiave (da ricordare)
#
# > **Audio Random Container non suona da solo**: serve sempre un **Audio Source** e un **trigger** (API o evento).
#
# ---

# %% [markdown]
# ## Audio Profiler – Cos’è
#
# L’**Audio Profiler** monitora **prestazioni audio**, **CPU**, **memoria** e **voci audio** della tua applicazione, frame per frame.
#
# **Apertura**
# `Window → Analysis → Profiler → Audio`
#
# ## Chart principale (timeline)
#
# | Voce                      | Cosa indica                  |
# | ------------------------- | ---------------------------- |
# | **Playing Audio Sources** | AudioSource attivi nel frame |
# | **Audio Voices**          | Canali audio (FMOD) in uso   |
# | **Total Audio CPU**       | CPU usata dall’audio         |
# | **Total Audio Memory**    | RAM usata dal sistema audio  |
#
# 👉 Le voci possono essere riordinate o nascoste dal legend.
#
# ## Details Pane – Simple View
#
# | Dato                                       | Significato                  |
# | ------------------------------------------ | ---------------------------- |
# | **Total / Playing / Paused Audio Sources** | Conteggio AudioSource        |
# | **Audio Clip Count**                       | Numero AudioClip in scena    |
# | **Audio Voices**                           | Canali audio totali          |
# | **Total Audio CPU**                        | CPU audio complessiva        |
# | **DSP CPU**                                | Mix, effetti, decompressione |
# | **Streaming CPU**                          | CPU per audio in streaming   |
# | **Other CPU**                              | Overhead audio               |
# | **Total Audio Memory**                     | Memoria audio totale         |
# | **Streaming File / Decode Memory**         | Buffer streaming             |
# | **Sample Sound Memory**                    | Audio decompressi in RAM     |
# | **Other Memory**                           | Overhead sistema audio       |
#
# Nota: la memoria audio è **pooled** (cresce fino a saturazione, poi viene riusata).
#
# ## Details Pane – Detailed View
#
# Mostra tutto il Simple View **+ log per-frame** degli eventi audio.
#
# ### Viste disponibili
#
# * **Channels**
# * **Groups**
# * **Channels and Groups** (consigliata)
#
# ## Colonne principali (Detailed)
#
# | Colonna               | Significato                       |
# | --------------------- | --------------------------------- |
# | **Object**            | GameObject con AudioSource        |
# | **Asset**             | AudioClip riprodotto              |
# | **Volume**            | Volume applicato dall’AudioSource |
# | **Audibility**        | Volume finale dopo mixer          |
# | **Plays**             | Numero di riproduzioni            |
# | **3D**                | Audio spazializzato               |
# | **Paused / Muted**    | Stato                             |
# | **Virtual**           | Voce sospesa (limite voci)        |
# | **OneShot / Looped**  | Tipo di playback                  |
# | **Distance**          | Distanza dal Listener             |
# | **MinDist / MaxDist** | Curve di attenuazione             |
# | **Time**              | Tempo corrente                    |
# | **Duration**          | Durata clip                       |
#
# ## Concetti chiave (da ricordare)
#
# * **Virtual = audio sacrificato** per priorità/udibilità
# * **DSP CPU alta** → troppi effetti / decompressioni
# * **Troppe voci** → rischio drop audio
# * **Streaming vs Decompress On Load** impatta CPU e RAM
#
# ### Frase da esame
#
# > **Audio Profiler = strumento per capire se l’audio sta saturando CPU, memoria o voci e perché.**
#
# ---

# %% [markdown]
# ## Ambisonic Audio – Cos’è
#
# Gli **Ambisonics** rappresentano un **campo sonoro completo a 360°** attorno al listener.
# Sono ideali per **VR**, **video 360°** e **ambienti lontani** (audio skybox).
#
# ## Concetti fondamentali
#
# | Concetto        | Spiegazione                                                      |
# | --------------- | ---------------------------------------------------------------- |
# | **Soundfield**  | Campo sonoro completo, non legato a singoli speaker              |
# | **Multicanale** | Audio salvato in più canali                                      |
# | **Rotazione**   | Il suono ruota con l’orientamento del listener (es. testa in VR) |
# | **Decoding**    | Conversione verso stereo / surround in base agli speaker         |
#
# ## Decoder ambisonico
#
# | Punto chiave      | Dettaglio                          |
# | ----------------- | ---------------------------------- |
# | Decoder built-in  | ❌ Non presente                     |
# | Decoder richiesto | ✅ Obbligatorio                     |
# | Dove si seleziona | Project Settings → Audio           |
# | Origine decoder   | Plug-in custom o SDK hardware (VR) |
#
# ## Importare un audio ambisonico
#
# | Requisito       | Valore             |
# | --------------- | ------------------ |
# | Formato         | WAV multicanale    |
# | Tipo            | B-format           |
# | Ordering        | ACN                |
# | Normalizzazione | SN3D               |
# | Inspector       | **Ambisonic = ON** |
#
# ## Riproduzione con Audio Source
#
# | Impostazione        | Stato                  |
# | ------------------- | ---------------------- |
# | AudioClip           | WAV ambisonico         |
# | Spatialize          | ❌ OFF                  |
# | Decoding            | Automatico via decoder |
# | Effetti AudioSource | ✅ Applicati            |
# | Reverb Zones        | ❌ Disabilitate         |
#
# 👉 La spazializzazione è **già inclusa nel decoding ambisonico**.
#
# ## Pipeline semplificata
#
# ```
# Ambisonic Clip
#    ↓
# Ambisonic Decoder
#    ↓
# Speaker Mode (Stereo / Surround)
#    ↓
# Audio Listener
# ```
#
# ## Supporto formati
#
# | Feature                | Supporto                |
# | ---------------------- | ----------------------- |
# | First Order Ambisonics | ✅                       |
# | Second Order           | ❌                       |
# | Binaural Stereo        | ✅ (dipende dal decoder) |
# | Quad / Surround        | ✅ (decoder-dipendente)  |
#
# Formato preferito:
#
# > **B-format + ACN + SN3D**
#
# ## Sviluppo decoder (alto livello)
#
# | Step | Azione                              |
# | ---- | ----------------------------------- |
# | 1    | Creare plug-in audio nativo         |
# | 2    | Impostare flag `IsAmbisonicDecoder` |
# | 3    | Compilare (dll / platform build)    |
# | 4    | Inserire in Assets                  |
# | 5    | Selezionarlo nelle Audio Settings   |
#
# ## Quando usarlo (regola pratica)
#
# ✔️ **VR / 360° / ambienti globali**
# ❌ **SFX locali (passi, colpi, UI)**
#
# ### Frase da esame
#
# > **Ambisonic Audio = soundfield 360° decodificato a runtime in base all’orientamento del listener e al setup degli speaker.**
#
# ---
