# %% [markdown]
# ## Run Unity from a Command-Line Interface — Riassunto
#
# ### Concetto generale
#
# Unity può essere **avviato dalla riga di comando** come un normale programma eseguibile, passando **argomenti** che ne modificano il comportamento all’avvio.
#
# Questo permette di usare Unity per:
#
# * automazione
# * build automatiche
# * test
# * pipeline CI/CD
#
# Gli argomenti sono separati da **uno spazio**
# (esempio: `-window-mode borderless`).
# ## Avvio di Unity da CLI
#
# ### Sintassi generale
#
# ```
# <UnityExecutablePath> -projectPath "Percorso/Al/Progetto"
# ```
#
# * Se il percorso contiene **spazi**, deve essere racchiuso tra **virgolette**.
# * In caso di problemi, consultare i **log di Unity**.
#
# ## Percorsi di avvio per sistema operativo
#
# ### Linux
#
# ```
# /home/<user>/Unity/Hub/Editor/<version>/Editor/Unity -projectPath <project path>
# ```
#
# ### macOS
#
# ```
# /Applications/Unity/Hub/Editor/<version>/Unity.app/Contents/MacOS/Unity -projectPath <project path>
# "/c/Program Files/Unity/Hub/Editor/2022.3.62f3/Editor/Unity.exe" -projectPath "C:/Users/DELL/Desktop/Epicode/Esercizi/Test_2D"
# ```
#
# ### Windows
#
# ```
# "C:\Program Files\Unity\Hub\Editor\<version>\Editor\Unity.exe" -projectPath "<project path>"
# ```
#
# **Nota Windows**
# Evitare percorsi che terminano con un singolo `\`.
# Usare `\\` oppure nessun backslash finale.
#
# ## Esecuzione di codice C# all’avvio
#
# Unity può eseguire **metodi statici** definiti negli script Editor al momento del lancio.
#
# Argomento principale:
#
# * `-executeMethod NomeClasse.NomeMetodo`
#
# Spesso usato insieme a:
#
# * `-batchmode` → avvio senza interfaccia grafica
# * `-quit` → chiusura automatica al termine
# ## Utilizzi tipici
#
# * Build automatizzate
# * Export di asset o pacchetti
# * Validazione del progetto
# * Test automatici
#
# ### Flusso concettuale
#
# ```
# Avvio Unity (CLI)
# → esecuzione metodo C#
# → completamento operazione
# → chiusura automatica
# ```
#
# ## Concetto chiave da ricordare
#
# > Unity non è solo un Editor grafico:
# > può essere trattato come **un processo di sistema completamente automatizzabile**.
#
# Vantaggi principali:
#
# * integrazione in pipeline professionali
# * build ripetibili
# * meno errori manuali
# * workflow scalabili
#
# **In sintesi:** usare la CLI trasforma Unity da strumento manuale a **motore di produzione**.
#
# ---

# %% [markdown]
# ## Unity Editor – Command Line Arguments (Concetto generale)
#
# Unity Editor e Unity Player possono essere **avviati da riga di comando** passando **argomenti** che:
#
# * controllano il comportamento all’avvio
# * configurano impostazioni
# * automatizzano workflow (build, test, CI/CD)
#
# Sintassi base:
#
# ```
# UnityExecutablePath [argomenti]
# ```
#
# Esempio:
#
# ```
# unity.exe -batchmode -quit -executeMethod MyClass.MyMethod
# "/c/Program Files/Unity/Hub/Editor/2022.3.62f3/Editor/Unity.exe" -createProject "C:\Users\DELL\Desktop\Epicode\Esercizi\test"
#
# ```
#
# ## Categorie principali di argomenti
#
# Unity organizza i parametri CLI in **aree funzionali**:
#
# * Configuration arguments
# * Batch mode arguments
# * Build arguments
# * Debugging arguments
# * Graphics / Platform arguments
# * License arguments
# * Profiler arguments
# * Editor / Hub special arguments
#
# Concettualmente:
#
# > ogni categoria controlla **una fase diversa del ciclo di vita dell’Editor**.
#
# ## Configuration arguments (i più importanti)
#
# ### Creazione e apertura progetti
#
# * `-createProject <path>`
#   → crea un **progetto vuoto** nel percorso indicato.
#
# * `-projectPath <path>`
#   → apre il progetto specificato (path assoluto o relativo).
#   → se contiene spazi → **virgolette obbligatorie**.
#
# * `-openfile <path>`
#   → apre Unity partendo da una scena o package.
#
# ### Automazione ed esecuzione codice
#
# * `-executeMethod Class.Method`
#   → esegue un **metodo statico** appena Unity apre il progetto.
#   Requisiti:
#
#   * script dentro cartella `Editor`
#   * metodo `static`
#   * eventuali parametri letti via `System.Environment.GetCommandLineArgs`
#
# Uso tipico:
#
# * CI
# * build
# * test
# * preparazione dati
#
# ### Modalità batch e chiusura
#
# * `-batchmode`
#   → avvia Unity **senza interfaccia grafica** (automazione).
#
# * `-quit`
#   → chiude Unity dopo aver completato le operazioni.
#
# ⚠️ Limiti di `-quit`:
#
# * può interrompere test in corso
#
# * può terminare async task
#
# * richiede flag aggiuntivi con Accelerator cache
#
# * `-quitTimeout <seconds>`
#   → tempo massimo di attesa prima della chiusura.
#
# ### Logging
#
# * `-logFile <path>`
#   → imposta dove scrivere il log dell’Editor.
#   Valore speciale:
#
#   * `-` → output su console
#
# * `-upmLogFile <path>`
#   → log separato per Unity Package Manager.
#
# ### Import / Export asset
#
# * `-exportPackage <assetPaths> <fileName>`
#   → esporta package Unity.
#
# * `-importPackage <path>`
#   → importa un `.unitypackage` **senza dialog UI**.
#
# ### Prestazioni e threading
#
# * `-job-worker-count <N>`
#   → numero massimo thread Job System.
#
# * `-gc-helper-count <N>`
#   → thread di supporto per garbage collection asset.
#
# ### Asset e import
#
# * `-overrideMaxTextureSize <N>`
#   → forza dimensione massima texture per **tutto il progetto**.
#
# * `-overrideTextureCompression`
#   → forza tipo di compressione texture.
#
# * `-disable-assembly-updater [assemblies]`
#   → disabilita aggiornamento automatico API per assembly specifici.
#
# Uso tipico:
#
# * import di DLL esterne
# * build da codice generato fuori da Unity
#
# ### Version control
#
# * `-vcsMode <mode>`
# * `-vcsModeSession <mode>`
#
# Imposta il sistema VCS:
#
# * Visible Meta Files
# * Hidden Meta Files
# * Perforce
# * PlasticSCM
#
# ### Utility
#
# * `-version`
#   → stampa la versione di Unity **senza avviare l’Editor**.
#
# * `-timestamps`
#   → aggiunge timestamp e thread ID ai log.
#
# * `-noUpm`
#   → disabilita Unity Package Manager.
#
# ## Concetto chiave (da ricordare)
#
# > Unity CLI non è interattiva:
# > è un **processo avviato con istruzioni precise**, che esegue e termina.
#
# Schema mentale:
#
# ```
# CLI → avvio Unity
#     → apertura progetto
#     → configurazione
#     → esecuzione codice
#     → chiusura
# ```
#
# ---
#
# ## Batch Mode — Concetto generale
#
# Il **Batch Mode** trasforma Unity da Editor interattivo a **processo automatico**.
#
# In batch mode:
#
# * Unity **non richiede input umano**
# * **non mostra finestre o dialog**
# * esegue istruzioni **fino alla fine e poi termina**
# * è pensato per **automazione**, **test**, **CI/CD**
#
# Concettualmente:
#
# > Unity smette di essere uno strumento “da usare”
# > e diventa uno **strumento da eseguire**
#
# ## `-batchmode` (il flag centrale)
#
# * Avvia Unity **senza interfaccia grafica**
# * Sopprime popup e finestre che bloccherebbero l’automazione
# * Se qualcosa fallisce (script, import, asset server):
#
#   * Unity **termina subito**
#   * restituisce **exit code 1**
#
# Regole importanti:
#
# * Può esistere **una sola istanza di Unity** per progetto
# * I log completi vanno nei **file di log**, non nella console
# * Se il progetto non è ancora importato:
#
#   * viene usata la **piattaforma di default**
#   * per cambiarla serve `-buildTarget`
#
# Verifica runtime:
#
# * `Application.isBatchMode` → true se Unity è in batch mode
#
# ## `-accept-apiupdate` (compatibilità API)
#
# Serve per:
#
# * permettere all’**API Updater** di girare in batch mode
#
# Senza questo flag:
#
# * l’API Updater **non viene eseguito**
# * possibili **errori di compilazione**
#
# Concettualmente:
#
# > autorizzi Unity a “modificare” il codice per mantenerlo compatibile
#
# ## `-ignorecompilererrors` (avvio forzato)
#
# * Unity **parte anche se ci sono errori di compilazione**
# * Utile solo in casi particolari (debug, analisi)
#
# ⚠️ Rischio:
#
# * codice non compilato
# * errori runtime difficili da diagnosticare
#
# ## `-nographics` (headless mode)
#
# * Unity **non inizializza il dispositivo grafico**
# * Consente l’esecuzione su:
#
#   * server
#   * macchine senza GPU
#   * ambienti CI
#
# Limitazioni:
#
# * niente Global Illumination baking
# * Enlighten richiede GPU
# * niente input simulato se la finestra non è in focus
# * **log disabilitati** a meno di usare `-logFile`
#
# Concettualmente:
#
# > Unity gira come “servizio”, non come applicazione grafica
#
# ## `-logFile` (fondamentale con batch)
#
# * Specifica dove scrivere i log
# * Necessario con `-nographics`
# * Senza log → debugging quasi impossibile
#
# ## `-upmPack` (UPM automation)
#
# * Usato in batch mode per:
#
#   * esportare
#   * firmare
#   * impacchettare un **Unity Package Manager package**
#
# Richiede:
#
# * `-batchmode`
# * credenziali Unity (`-username`, `-password`)
# * organization ID
#
# Concettualmente:
#
# > Unity usato come **tool di distribuzione**, non come Editor
#
# ## Modello mentale complessivo
#
# ```
# Batch Mode =
# Unity come job automatico
#
# → avvio
# → esecuzione task
# → successo o fallimento
# → exit code
# ```
#
# Non:
#
# * editing
# * testing manuale
# * interazione
#
# Ma:
#
# * pipeline
# * script
# * automazione industriale
#
# ## In sintesi (da ricordare)
#
# * `-batchmode` è **obbligatorio** per automazione
# * Unity in batch:
#
#   * non chiede nulla
#   * non aspetta nessuno
# * Errori → exit immediato
# * `-accept-apiupdate` evita problemi di compatibilità
# * `-nographics` = Unity “headless”
# * I **log** diventano la tua unica UI
#
# ---
#
# ## Build Arguments — Concetto generale
#
# I **Build arguments** permettono di usare Unity come **build system automatico**, senza aprire l’Editor manualmente.
#
# In pratica:
#
# > Unity viene avviato → configurato per una piattaforma → compila → produce un Player → termina
#
# Sono fondamentali per:
#
# * CI/CD
# * build ripetibili
# * multi-piattaforma
# * pipeline professionali
#
# ## 1. Build Profile: separare configurazione e codice
#
# ### `-activeBuildProfile <path>`
#
# Imposta un **Build Profile** come attivo.
#
# Concettualmente:
#
# * il **Build Profile** è una *preset di build*
# * contiene:
#
#   * piattaforma
#   * opzioni
#   * **scripting defines**
#
# Caratteristiche importanti:
#
# * il path è **relativo alla root del progetto**
# * i *scripting defines* del profilo:
#
#   * **si aggiungono** a quelli esistenti
#   * **non li sovrascrivono**
# * se usato con `-executeMethod`:
#
#   * Unity **ricompila gli script**
#   * poi esegue il metodo
#
# 👉 Questo abilita workflow tipo:
#
# > stesso progetto → build Windows → build Linux → build WebGL
# > **in una singola sessione batch**
#
# ## 2. Costruire il Player (build vera e propria)
#
# ### `-build <path>`
#
# Costruisce un Player usando il **Build Profile attivo**.
#
# Concetti chiave:
#
# * il path indica **dove salvare la build**
# * per alcune piattaforme è obbligatoria l’estensione:
#
#   * `.exe`
#   * `.app`
#   * ecc.
#
# > Qui Unity non decide *come* buildare,
# > ma *dove* scrivere l’output.
#
# ## 3. Build dirette per piattaforma (shortcut)
#
# Questi flag **saltano parte della configurazione** e dicono direttamente cosa buildare.
#
# ### Linux
#
# * `-buildLinux64Player`
# * `-buildLinuxHeadlessSimulation`
#   (server / simulazioni senza rendering)
#
# ### macOS
#
# * `-buildOSXUniversalPlayer`
#
# ### Windows
#
# * `-buildWindowsPlayer` (32-bit)
# * `-buildWindows64Player` (64-bit)
#
# Concettualmente:
#
# > sono comandi “one-shot”
# > → piattaforma già implicita
# > → meno flessibili, ma più rapidi
#
# ## 4. Selezione del target prima del build
#
# ### `-buildTarget <name>`
#
# Imposta **la piattaforma attiva** prima che Unity carichi il progetto.
#
# Serve quando:
#
# * il progetto non è ancora importato
# * sei in `-batchmode`
# * vuoi forzare una piattaforma specifica
#
# Target comuni:
#
# * `win`, `win64`
# * `linux64`
# * `osxuniversal`
# * `webgl`
# * `android`, `ios`
# * `windowsstoreapps`
# * `visionos`, `tvos`
#
# Concettualmente:
#
# > stai dicendo a Unity
# > “pensa come se fossi su questa piattaforma”
#
# ## 5. Sub-target Standalone
#
# ### `-standaloneBuildSubtarget <name>`
#
# Valido per piattaforme Standalone.
#
# Opzioni:
#
# * `Player` → build normale
# * `Server` → build server-only (headless)
#
# Concetto:
#
# > stesso codice,
# > ma **ruolo diverso del Player**
#
# ## Modello mentale completo (importante)
#
# ```
# CLI
# → avvio Unity
# → selezione Build Profile
# → selezione Target / Subtarget
# → compilazione
# → generazione Player
# → uscita
# ```
#
# Unity diventa:
#
# * **compiler**
# * **packager**
# * **exporter**
#
# non più solo Editor.
#
# ## In sintesi (da ricordare)
#
# * **Build Profile** = configurazione + defines
# * `-activeBuildProfile` prepara il contesto
# * `-build` produce l’output
# * `-buildTarget` forza la piattaforma
# * flag specifici (Windows/Linux/macOS) = shortcut
# * tutto è pensato per **automazione e CI**
#
# ---
#
# Ecco una **riscrittura concettuale, ordinata e da notebook**, pensata per capire **perché** esistono questi argomenti e **quando** usarli, non per memorizzare liste.
#
# ---
#
# # Unity CLI — Cache, Debug, Graphics, License
#
# ## Spiegazione concettuale
#
# ## 1. Unity Accelerator (Cache Server) — Concetto
#
# Unity Accelerator è un **cache server** che conserva:
#
# * risultati di import degli asset
# * metadati
# * shader cache
#
# Scopo:
#
# > evitare di reimportare tutto ogni volta
# > velocizzare apertura progetto, build e CI
#
# Con la CLI puoi **forzare** il comportamento del cache server, **ignorando le Editor Preferences**.
#
# ---
#
# ### Abilitazione e connessione
#
# * `-EnableCacheServer`
#   → abilita Unity Accelerator
#
# * `-cacheServerEndpoint <host:port>`
#   → indirizzo del server (default `10080`)
#
# Concetto:
#
# > Unity non “cerca” il server,
# > glielo **dichiari esplicitamente**
#
# ### Isolamento dei dati (namespace)
#
# * `-cacheServerNamespacePrefix <prefix>`
#
# Serve per:
#
# * separare cache tra progetti
# * separare cache tra versioni Unity
#
# Concettualmente:
#
# > stesso server, **cache logiche diverse**
#
# ### Upload / Download (controllo fine)
#
# * `-cacheServerEnableDownload true|false`
# * `-cacheServerEnableUpload true|false`
#
# Uso tipico:
#
# * CI che **scarica ma non carica**
# * build locali che **caricano risultati**
#
# ### Sincronizzazione e sicurezza
#
# * `-cacheServerWaitForConnection <ms>`
#   → quanto aspettare il server prima di partire
#
# * `-cacheServerWaitForUploadCompletion`
#   → evita che Unity chiuda (`-quit`) prima di finire gli upload
#
# Concetto chiave:
#
# > senza questo flag, puoi **perdere cache** in batch mode
#
# ### Ottimizzazione trasferimenti
#
# * `-cacheServerDownloadBatchSize <N>`
#   → dimensione batch download (default 128)
#
# * `-cacheServerUploadExistingImports`
#
# * `-cacheServerUploadAllRevisions`
#
# * `-cacheServerUploadExistingShaderCache`
#
# Questi controllano **quanto storico** caricare nel server.
#
# ## 2. Debugging arguments — Concetto
#
# Questi flag servono quando Unity è:
#
# * sotto debug
# * in sviluppo engine / plugin
# * in ambienti complessi (XR, native plugin)
#
# Concettualmente:
#
# > non per il gameplay
# > ma per **capire cosa sta succedendo sotto il cofano**
#
# ### Debugger
#
# * `-disableManagedDebugger`
#   → disabilita socket debugger C#
#
# * `-wait-for-managed-debugger`
#
# * `-wait-for-native-debugger`
#
# Concetto:
#
# > Unity **si ferma** e aspetta il debugger prima di partire
#
# ---
#
# ### Shader e rendering debug
#
# * `-diag-debug-shader-compiler`
#   → forza un solo shader compiler, timeout lungo
#
# * `-stackTraceLogType Full|ScriptOnly|None`
#   → livello di dettaglio degli stack trace
#
# ### Performance e analisi
#
# * `-log-memory-performance-stats`
#   → dump dettagliato su memoria e performance alla chiusura
#
# * `-enableCodeCoverage`
#   → abilita coverage (test automatici)
#
# ## 3. Graphics API arguments — Concetto
#
# Questi argomenti **forzano l’API grafica**, ignorando Player Settings.
#
# Uso tipico:
#
# * debugging driver
# * problemi platform-specific
# * test XR / native plugin
#
# Concetto chiave:
#
# > stesso progetto, **diverso backend grafico**
#
# ### Forzare API
#
# * `-force-d3d11` / `-force-d3d12` (Windows)
# * `-force-vulkan`
# * `-force-opengl`
# * `-force-glcore`, `-force-glcoreXY`
# * `-force-gles`, `-force-glesXY`
#
# ### GPU selection
#
# * `-force-device-index <N>`
#
# Serve per:
#
# * scegliere GPU integrata vs dedicata
# * debug laptop / multi-GPU
#
# Concetto:
#
# > Unity usa **quella GPU**, non quella “preferita”
#
# ## 4. License arguments — Concetto
#
# Questi flag permettono di:
#
# * attivare
# * restituire
# * gestire licenze **senza UI**
#
# Fondamentali per:
#
# * CI
# * build server
# * macchine headless
#
# ### Attivazione manuale
#
# * `-createManualActivationFile`
#   → genera file di richiesta licenza
#
# * `-manualLicenseFile <file.ulf>`
#   → applica licenza manuale
#
# ### Licenze automatiche
#
# * `-serial <serial-key>`
#   → attiva licenza (seriale o named user)
#
# ⚠️ Regola fondamentale:
#
# > `-serial` **richiede** `-batchmode`
# > ed è buona pratica usare anche `-quit`
#
# ### Rilascio licenza
#
# * `-returnlicense`
#   → restituisce la licenza attiva
#
# Concetto:
#
# > libera la licenza prima di spegnere o migrare una macchina
#
# ## Modello mentale complessivo
#
# ```
# CLI
# → Unity come processo
# → cache controllata
# → rendering forzato
# → debug avanzato
# → licenza gestita
# → exit
# ```
#
# Unity diventa:
#
# * **tool industriale**
# * **build worker**
# * **nodo di pipeline**
#
# non più solo Editor.
#
# ## Sintesi finale (da ricordare)
#
# * Cache Server = **velocità e coerenza**
# * Debug args = **diagnostica profonda**
# * Graphics args = **controllo hardware**
# * License args = **automazione legale**
# * Tutto è pensato per **ambienti professionali e CI**
#
# ---
#
# # Unity CLI — Argomenti avanzati (Metal, Profiler, Special)
#
# ## 1. Metal arguments (solo macOS)
#
# ### Concetto
#
# Questi argomenti controllano **come Unity usa Metal**, l’API grafica di Apple.
# Servono soprattutto per:
#
# * debugging grafico
# * ottimizzazione energetica
# * profiling su macOS / Apple Silicon
#
# Non hanno senso fuori dall’ecosistema Apple.
#
# ### Argomenti principali
#
# * `-force-metal`
#   → forza l’uso di **Metal** come API grafica dell’Editor.
#   Concetto: ignora Player Settings, **Metal diventa obbligatorio**.
#
# * `-force-low-power-device`
#   → forza l’uso della **GPU a basso consumo** (tipicamente su laptop).
#   Utile per test di:
#
#   * consumo energetico
#   * thermal throttling
#   * performance “worst case”.
#
# * `-enable-metal-capture`
#   → abilita la cattura Metal dall’interno dell’Editor.
#   Usato per analisi con strumenti come **Xcode GPU Frame Capture**.
#
# ## 2. Profiler arguments
#
# ### Concetto
#
# Questi argomenti permettono di **profilare Unity automaticamente all’avvio**, senza interazione manuale.
#
# Servono per:
#
# * analisi performance
# * test automatici
# * confronti tra build
# * CI con metriche
#
# Unity diventa:
#
# > un processo che **misura sé stesso**
#
# ### Argomenti principali
#
# * `-deepprofiling`
#   → abilita **Deep Profiling** CPU.
#   Concetto:
#
#   * massima precisione
#   * overhead molto alto
#   * non per produzione.
#
# * `-profiler-enable`
#   → avvia il Profiler automaticamente:
#
#   * Player → come “Autoconnect Profiler”
#   * Editor → Profiler attivo all’avvio
#
# * `-profiler-log-file <file.raw>`
#   → salva i dati del Profiler in un file `.raw`.
#   Utile per:
#
#   * analisi offline
#   * confronti automatici
#
# * `-profiler-capture-frame-count <N>`
#   → numero di frame da catturare (Player only).
#
# * `-profiler-maxusedmemory <bytes>`
#   → imposta quanta memoria può usare il Profiler.
#   Serve per:
#
#   * sessioni lunghe
#   * profiling pesante
#
# ## 3. Unity Editor special arguments
#
# ⚠️ **Da usare solo in casi estremi** o su indicazione di Unity Support.
#
# ### Concetto
#
# Questi flag **modificano il comportamento interno dell’Editor** e possono:
#
# * causare perdita di dati
# * corrompere progetti
# * rendere instabile l’ambiente
#
# ### Argomenti principali
#
# * `-enableIncompatibleAssetDowngrade`
#   → forza il downgrade di asset creati con versioni Unity più recenti.
#   Concetto:
#
#   > “Prova comunque, anche se è pericoloso”
#
# * `-giCustomCacheLocation "<path>"`
#   → imposta una cartella custom per la cache GI **solo per la sessione corrente**.
#   Utile per:
#
#   * dischi separati
#   * macchine CI
#
# * `-rebuildLibrary`
#   → cancella la cartella `Library` e forza un **reimport completo**.
#   Usato quando:
#
#   * database asset corrotto
#   * Unity non riesce ad avviarsi
#
# ## 4. Unity Hub special arguments
#
# ### Concetto
#
# Servono per gestire il **collegamento tra Unity Editor e Unity Hub**.
#
# ⚠️ Oggi:
#
# > **sono già attivi di default**
# > e non vanno usati manualmente, salvo indicazione esplicita.
#
# ### Argomenti
#
# * `-useHub`
#   → avvia l’Editor con integrazione Hub
#
# * `-hubIPC`
#   → abilita comunicazione Editor ↔ Hub
#
# * `-hubSessionId`
#   → identifica una sessione Hub specifica
#
# ## Modello mentale finale
#
# ```
# CLI
# ├─ Rendering (Metal / Graphics)
# ├─ Profiling (performance automatica)
# ├─ Recovery (Editor special)
# └─ Integrazione tooling (Hub)
# ```
#
# Questi argomenti **non servono al gameplay**, ma a:
#
# * debugging avanzato
# * infrastruttura
# * supporto
# * produzione industriale
#
# ## Sintesi da ricordare
#
# * **Metal args** → controllo GPU Apple
# * **Profiler args** → misurazione automatica
# * **Editor special** → recovery / emergenza
# * **Hub special** → integrazione interna (di solito invisibile)
#
# ---

# %% [markdown]
# # Unity Player — Command Line Arguments
#
# ## Spiegazione concettuale
#
# ## Concetto generale
#
# I **Player command line arguments** controllano **come gira il gioco compilato**, non l’Editor.
#
# Servono per:
#
# * automazione
# * test
# * debugging
# * profiling
# * configurazione runtime (grafica, finestra, log, GPU)
#
# Concettualmente:
#
# > l’Editor serve a **creare**
# > il Player CLI serve a **eseguire e osservare**
#
# ⚠️ Non funzionano su Web (WebGL).
#
# ## 1. Modalità di esecuzione (headless / automation)
#
# ### `-batchmode`
#
# * Avvia il Player **senza rendering e senza input**
# * Nessuna finestra, nessuna interazione
#
# Uso tipico:
#
# * simulazioni
# * server
# * test automatici
#
# Concetto:
#
# > il gioco diventa un **processo computazionale**
#
# ### `-nographics`
#
# * Nessuna inizializzazione GPU
# * Usabile solo con `-batchmode`
#
# Limiti:
#
# * log disabilitati (serve `-logFile`)
# * niente rendering
# * niente stereo
# * niente GI
#
# Concetto:
#
# > Player “headless” puro, da server o CI
#
# ## 2. Logging e diagnostica
#
# ### `-logFile <path>` / `-logfile`
#
# * Specifica dove scrivere i log
# * `-` → output su console
#
# ### `-nolog`
#
# * Disabilita completamente i log
#
# ### `-timestamps`
#
# * Aggiunge timestamp e thread ID ai log
#
# ### `-log-memory-performance-stats`
#
# * Dump dettagliato di memoria alla chiusura
#
# Concetto:
#
# > i log sono la **UI invisibile** del Player
#
# ## 3. Debugging (runtime)
#
# ### `-wait-for-managed-debugger`
#
# ### `-wait-for-native-debugger`
#
# * Il Player **si ferma** all’avvio
# * Mostra il PID
# * Aspetta il debugger
#
# Uso:
#
# * debugging C#
# * debugging plugin nativi
#
# Concetto:
#
# > il Player non “parte” finché non sei pronto
#
# ## 4. Controllo grafico e GPU
#
# ### Forzare API grafiche
#
# * `-force-d3d11`, `-force-d3d12` (Windows)
# * `-force-vulkan`
# * `-force-metal` (macOS)
# * `-force-glcore`, `-force-glcoreXY`
# * `-force-opengl`
# * `-force-gles`, `-force-glesXY`
#
# Concetto:
#
# > stesso gioco, **backend grafico diverso**
#
# ### Selezione GPU
#
# * `-force-device-index <N>`
# * `-force-low-power-device` (macOS)
#
# Uso:
#
# * laptop (integrata vs dedicata)
# * debug multi-GPU
#
# ### Altri flag grafici
#
# * `-disable-gpu-skinning`
# * `-no-stereo-rendering`
# * `-force-gfx-direct` (render single-thread)
#
# Concetto:
#
# > ridurre complessità per **debug e test**
#
# ## 5. Risoluzione e finestra
#
# ### Dimensioni e modalità
#
# * `-screen-width`
# * `-screen-height`
# * `-screen-fullscreen 0|1`
# * `-window-mode exclusive|borderless`
# * `-popupwindow`
#
# ### Monitor
#
# * `-monitor N` (1-based)
#
# Concetto:
#
# > controlli l’ambiente visivo **senza ricompilare**
# ## 6. Esecuzione controllata
#
# ### `-single-instance`
#
# * Una sola istanza del Player
# * Se già aperta → viene focalizzata
#
# Utile per:
#
# * tool
# * launcher
# * simulazioni
#
# ### `-parentHWND` (Windows)
#
# * Incapsula il Player dentro un’altra app
# * Usato per:
#
#   * tool embedded
#   * simulazioni
#   * applicazioni ibride
#
# Concetto:
#
# > Unity come **componente**, non app standalone
#
# ## 7. Prestazioni avanzate / shader
#
# ### `-max-async-pso-job-count`
#
# * Controlla thread per PSO (DX12 / Metal / Vulkan)
# * Usato con shader warmup
#
# Concetto:
#
# > controllo fine del **costo shader runtime**
#
# ## Modello mentale complessivo
#
# ```
# Player CLI
# ├─ modalità (headless / interactive)
# ├─ logging
# ├─ debugging
# ├─ grafica / GPU
# ├─ finestra / monitor
# └─ performance
# ```
#
# Il Player CLI **non crea**,
# **esegue**.
#
# ## Sintesi da ricordare
#
# * Player CLI = controllo del **runtime**
# * `-batchmode` + `-nographics` = server / CI
# * Forzare API = debug platform-specific
# * Log = unica fonte di verità
# * Debugger flags = controllo totale sull’avvio
# * Window flags = test rapidi senza rebuild
#
# ---
