# %% [markdown]
# # **Modulo 1: Dal Silenzio al Suono**
#
# Il suono definisce il modo in cui viviamo i mondi interattivi. Aumenta l'immersione, guida il giocatore e veicola emozioni e narrazione.
#
# ---
#
# ### **Esplora Wwise**
#
# Prendi confidenza con l'interfaccia di **Wwise**.
#
# 1.  Dal menu **Layouts**, assicurati che sia selezionato **Designer** (Wwise può aprirsi nell'ultimo layout usato).
# 2.  Nel **Project Explorer**, seleziona **Audio Devices** per visualizzare tutte le viste disponibili.
#
# L'interfaccia è composta da una **barra dei menu**, una **barra degli strumenti** e varie **viste**. Le viste cambiano in base al **layout** selezionato, ovvero un'area di lavoro progettata per un flusso specifico. Il layout **Designer** è quello principale e verrà usato per tutta la certificazione.
#
# *   Le viste possono essere **ridimensionate** trascinando i bordi.
# *   Il **Project Explorer** contiene le **Default Work Units**, che userai durante il corso. Nei progetti reali, le **Work Units** permettono a più team di lavorare in parallelo per poi integrare il lavoro.
#
# ---
#
# ### **Gerarchia Audio di Wwise (Project Explorer)**
#
# La sezione **Audio** del **Project Explorer** è organizzata in **4 categorie principali**:
#
# 1.  **Audio Devices**
#     *   Definisce l'**output audio fisico** (casse, cuffie, ecc.).
#
# 2.  **Master-Mixer Hierarchy**
#     *   La gerarchia dei **bus audio**: gestisce il routing, il mix, il volume e gli effetti globali.
#
# 3.  **Actor-Mixer Hierarchy**
#     *   Contiene i **suoni e gli effetti sonori (SFX)** del gioco (oggetti audio, contenitori, logica di riproduzione).
#
# 4.  **Interactive Music Hierarchy**
#     *   Gestisce la **musica interattiva** (segmenti, switch, transizioni musicali).
#
# 👉 **Mnemonica rapida**:
# **Devices → Uscita**, **Master → Mix**, **Actor → Suoni**, **Music → Musica**
#
# ---
#
# ### **Il Flusso di Lavoro Base di Wwise**
#
# Un tipico flusso per portare un suono nel gioco segue questi passaggi chiave:
#
# 1.  **Importa un Suono**
#     *   Un file audio viene importato in Wwise e rappresentato da un **oggetto Sound SFX** – il "contenitore" logico attraverso cui il suono verrà riprodotto.
#
# 2.  **Crea un Event**
#     *   L'**Event** collega il suono a un'azione di gioco. È il **ponte tra gameplay e audio**: quando il gioco invoca una "Game Call", Wwise risponde eseguendo l'Event.
#
# 3.  **Testa l'Audio in Wwise**
#     *   Puoi riprodurre sia il suono che l'Event direttamente nell'editor, simulando il comportamento in-game.
#
# 4.  **Crea una SoundBank**
#     *   Le risorse audio e la loro logica vengono impacchettate in una **SoundBank**, che è il pacchetto di contenuti finale caricato dal gioco.
#
# 5.  **Genera la SoundBank e Testa nel Gioco**
#     *   La SoundBank viene generata per la piattaforma di destinazione e caricata dal gioco, permettendoti di sentire il suono durante il gameplay effettivo.
#
# ---
#
# ### **Concetto Fondamentale da Ricordare**
#
# > **In Wwise non riproduci file audio, ma attivi comportamenti audio.**
# > Il gioco chiama un Event → Wwise decide *cosa* suona e *come*.
#
# Questo ciclo fondamentale è la base di **tutta l'implementazione audio per videogiochi con Wwise**.
#
# ---
