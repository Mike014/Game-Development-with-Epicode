# %% [markdown]
# # *Animazioni in Unity*
#
# ---
#
# ## 1. Overview – Perché l’animazione è centrale in Unity
#
# L’animazione è uno degli elementi chiave che trasformano un progetto Unity da “funzionante” a **vivo**.
# Serve per:
#
# * gameplay (azioni, reazioni, feedback)
# * narrazione (scene, stati emotivi, ritmo)
# * interfaccia (transizioni UI, menu, feedback visivi)
#
# In Unity esistono **due grandi categorie di animazioni**:
#
# 1. **Animazioni importate** da software esterni (Maya, Blender, ecc.)
# 2. **Animazioni create direttamente nell’Editor**
#
# Un progetto reale usa quasi sempre **entrambe**, in modo complementare.
#
# ## 2. Before you begin – Il contesto di partenza
#
# Questa esperienza formativa **non è per principianti assoluti**:
#
# * dà per scontata una conoscenza base dell’Editor di Unity
# * rimanda a percorsi introduttivi se sei nuovo
#
# Il focus non è “imparare Unity”, ma **imparare l’animazione dentro Unity**.
# La preparazione tecnica (Hub aggiornato, progetto già pronto, pannelli aperti) serve solo a **rimuovere attriti**, così da concentrarsi sui concetti.
#
# ## 3. Creative Core: Animation – Obiettivo didattico
#
# L’obiettivo del percorso è **capire come e perché si usano le animazioni in Unity**, non solo come crearle.
#
# In particolare impari a:
#
# * creare animazioni **in-editor**
# * applicare principi classici dell’animazione
# * collegare animazioni a **input e stati interattivi**
# * lavorare con animazioni **importate**
# * combinare più animazioni in una scena coerente
#
# Il risultato finale non è solo tecnico:
# è la capacità di **pensare l’animazione come parte del design interattivo**.
#
# ## 4. Cosa fa un Animator in Unity
#
# Un animator in Unity non anima solo personaggi:
#
# * oggetti
# * ambienti
# * cutscene
# * interfacce
# * elementi di gameplay
#
# > In Unity, **quasi tutto può essere animato**.
#
# ### Ruolo ibrido
#
# L’animator può:
#
# * lavorare **fuori da Unity** (creazione asset complessi)
# * lavorare **dentro Unity** (integrazione, controllo, stati)
#
# Deve spesso:
#
# * configurare animazioni importate
# * lavorare con **Animator Controller**
# * collaborare con programmatori
# * capire (anche solo a livello base) **come gli script attivano le animazioni**
#
# ### Strumenti tipici
#
# Gli strumenti esterni più comuni sono:
#
# * Autodesk Maya – standard industriale
# * Autodesk 3ds Max – storico nel game dev
# * Blender – gratuito, sempre più usato anche in ambito pro
#
# Unity diventa il **punto di orchestrazione**, non sempre il luogo di creazione primaria.
#
# ## 5. Perché l’animazione è importante (concettualmente)
#
# L’animazione è spesso definita **“l’illusione della vita”**.
#
# Non è solo movimento:
#
# * un oggetto che cade → fisica
# * una persona che cammina → animazione
#
# La differenza è **l’intenzione**.
#
# La fisica calcola.
# L’animazione **comunica**:
#
# * peso
# * carattere
# * emozione
# * decisione
# * stato interno
#
# In un’esperienza interattiva:
#
# * l’animazione guida la percezione del giocatore
# * rende leggibili le azioni
# * dà credibilità al mondo
# * trasmette informazioni senza parole
#
# Senza animazione, un progetto può funzionare.
# Con l’animazione, **può essere creduto**.
#
# ### Sintesi finale in una frase
#
# 👉 In Unity, l’animazione non è decorazione: è **linguaggio**, **intenzione** e **ponte tra codice e percezione umana**.
#
# Se vuoi, nel prossimo messaggio posso:
#
# * riassumere **Animator, Animation, Controller e States** in modo schematico
# * oppure collegare questi concetti al **gameplay design** o alla **UI**
#
# ---

# %% [markdown]
# ## *Sistema di animazione in Unity* – Concetti fondamentali
#
# Il sistema di animazione di **Unity** è composto da **asset**, **componenti** e **strumenti** che lavorano insieme per controllare il movimento e le variazioni di proprietà dei GameObject nel tempo.
#
# ## 1. Animation Clips – *Il “cosa” si anima*
#
# Le **Animation Clip** sono i **contenitori dei dati di animazione**.
#
# Concettualmente:
#
# * descrivono *come* cambiano certe proprietà nel tempo
# * non decidono *quando* o *perché* partire
#
# Caratteristiche chiave:
#
# * possono essere **create direttamente in Unity** oppure **importate** da software esterni
# * contengono curve che modificano:
#
#   * Transform (posizione, rotazione, scala)
#   * proprietà dei componenti
#   * GameObject figli (gerarchia)
# * una clip **non è legata a un solo oggetto**: può essere riutilizzata
#
# Idea chiave:
#
# > Una Animation Clip è una **registrazione temporale di variazioni**, non una logica.
#
# ## 2. Animation Controller – *La logica delle animazioni*
#
# L’**Animation Controller** è un **asset** che definisce *quando* e *come* le animazioni vengono riprodotte.
#
# Concettualmente:
#
# * è una **macchina a stati**
# * gestisce:
#
#   * stati (Idle, Walk, Run, ecc.)
#   * transizioni
#   * condizioni (parametri)
#   * blending tra animazioni
#
# Non anima direttamente nulla, ma:
#
# * decide **quale Animation Clip è attiva**
# * in base a input, variabili o eventi
#
# Idea chiave:
#
# > L’Animation Controller è il **cervello** che decide il comportamento animato.
#
# ## 3. Animator (component) – *Il collegamento al GameObject*
#
# L’**Animator** è il **componente runtime** attaccato al GameObject.
#
# Concettualmente:
#
# * è il **ponte tra GameObject e Animation Controller**
# * tiene lo stato corrente delle animazioni
# * contiene i **dati runtime** (parametri, stato attuale, transizioni)
#
# Aspetto fondamentale:
#
# * più Animator possono usare **lo stesso Animation Controller**
# * **ognuno ha il suo stato indipendente**
#
# Idea chiave:
#
# > L’Animator è l’**esecutore**, non il progettista.
#
# ## Schema mentale rapido
#
# ```
# Animation Clip     →   cosa cambia nel tempo
# Animation Controller →   quando e perché cambia
# Animator (component) →   chi esegue il cambiamento
# ```
#
# ## 4. Animation Window – *Lo strumento di editing*
#
# La **Animation Window** è l’editor dove:
#
# * crei nuove Animation Clip
# * modifichi clip esistenti
# * registri keyframe
#
# Serve per:
#
# * lavorare sulle animazioni **in-editor**
# * modificare:
#
#   * singole clip dal Project
#   * tutte le clip di un Animator selezionato
#
# È uno strumento **tecnico**, non logico:
#
# * non decide flussi
# * modifica solo i dati dell’animazione
#
# Idea chiave:
#
# > Animation Window = **foglio di montaggio dell’animazione**.
#
# ## 5. Proprietà animate – *Cosa può essere animato*
#
# In Unity puoi animare:
#
# * proprietà di un GameObject
# * proprietà dei suoi componenti
# * proprietà dei GameObject figli (gerarchia)
#
# Ogni proprietà animata:
#
# * occupa **una traccia**
# * è collegata a:
#
#   * nome del GameObject
#   * percorso gerarchico
#
# Funzionalità chiave:
#
# * vedere il valore nel tempo (Timeline)
# * modificare keyframe
# * cambiare frame rate
# * scegliere quale clip stai editando
#
# Nota importante (molto pratica):
#
# * se una traccia diventa **gialla**, Unity non trova più quel GameObject
# * rinominare la traccia permette di ricollegarla
#
# Idea chiave:
#
# > Le animazioni in Unity sono **sensibili alla struttura della scena**.
#
# ## Concetto finale unificante
#
# Il sistema di animazione di Unity è separato in modo molto netto:
#
# * **dati** (Animation Clip)
# * **logica** (Animation Controller)
# * **runtime** (Animator)
# * **editing** (Animation Window)
#
# Questo rende il sistema:
#
# * modulare
# * riutilizzabile
# * scalabile
# * integrabile con il codice
#
# Se vuoi, nel prossimo messaggio posso:
#
# * fare un **confronto diretto Animation vs Animator**
# * spiegarti **come il codice dialoga con l’Animator**
# * oppure collegare tutto a **casi reali di gameplay (Idle/Run/Attack)**
#
# ---
